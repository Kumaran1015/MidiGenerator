# %%
import glob
import numpy as np
import pygame
import os
import midi
import pretty_midi
from midi_manipulation import *

# %%
def  findRange(pattern):
    mini = 200
    maxi = -1
    for i in range(len(pattern)):
        if isinstance(pattern[i], midi.NoteEvent):
            if(pattern[i].pitch < mini):
                mini = pattern[i].pitch
            if(pattern[i].pitch > maxi):
                maxi = pattern[i].pitch
    return maxi-mini,mini

# %%
def splitIntoBar(stateMatrix):
    (rows,cols) = stateMatrix.shape
    ret = []
    ret2 = []
    flag = False
    for j in range(12):
        n = np.zeros((rows,cols))
        for k in range(rows):
            pos = np.argmax(stateMatrix[k])
            if pos <= 59:
                base = 48
            else:
                base = 60
            n[k , (pos+1)%12 + base] = 1
        stateMatrix = n
        i = 1
        while rows >= i*16:
            midi.write_midifile("chroma_temp.mid", noteStateMatrixToMidi(stateMatrix[(i)*16-16 : (i)*16,:]))
            midi_data = pretty_midi.PrettyMIDI('chroma_temp.mid')
            try:
                chroma = midi_data.get_chroma(fs=1.0/midi_data.get_end_time())
                ret.append([stateMatrix[(i)*16-16 : (i)*16,:]])
                ret2.append(chroma)
            except ZeroDivisionError:
                flag = True
            i += 1
        return np.asarray(ret), np.asarray(ret2), flag

# %%
cnt = 0
errors = 0
ignored = 0
Cur_X = []
chromaVec = []
for root, subFolders, files in os.walk('../TheoryTab'):
        for f in files:
            if '.mid' in f:
                try:
                    pattern = midi.read_midifile(os.path.join(root, f))
                    cnt += 1
                    print "Processing file ",f,"#", cnt
                    p = midi.Pattern(resolution = pattern.resolution)
                    if len(pattern) < 2:
                        print f, 'missing melody track'
                        errors += 1
                        continue
                    p.append(pattern[0])
                    p.append(pattern[1])
                    span, mini = findRange(pattern[1])
                    if span <= 24:
                        stateMatrix = np.array(midiToNoteStateMatrix(p, 48 - mini))
                        res, res2, flag = splitIntoBar(stateMatrix)
                        Cur_X.extend(res)
                        chromaVec.extend(res2)
                        if flag == True:
                            ignored += 1
                except TypeError:
                    print f, 'raised error'
                    errors += 1

print errors, ignored, cnt
# Out:
# Processing file  Summertime Sadness.midi # 1
# Summertime Sadness.midi raised error
# Processing file  King of Anything.midi # 2
# King of Anything.midi raised error
# Processing file  Any Man Of Mine.midi # 3
# Any Man Of Mine.midi raised error
# Processing file  Sk8er Boi.midi # 4
# Sk8er Boi.midi raised error
# Processing file  Me4U ft Morrie.midi # 5
# Me4U ft Morrie.midi raised error
# Processing file  Stand Still feat Micky Green - Wave Racer Remix.midi # 6
# Stand Still feat Micky Green - Wave Racer Remix.midi raised error
# Processing file  Heavenly Star.midi # 7
# Heavenly Star.midi raised error
# Processing file  Hi.midi # 8
# Hi.midi raised error
# Processing file  I Need Your Love.midi # 9
# I Need Your Love.midi raised error
# Processing file  Genghis Khan.midi # 10
# Genghis Khan.midi raised error
# Processing file  Speed Of Sound.midi # 11
# Speed Of Sound.midi raised error
# Processing file  Lipstick.midi # 12
# Lipstick.midi raised error
# Processing file  Speechless.midi # 13
# Speechless.midi raised error
# Processing file  Do Me Good.midi # 14
# Do Me Good.midi raised error
# Processing file  The Man Who Can't Be Moved.midi # 15
# The Man Who Can't Be Moved.midi raised error
# Processing file  Hollaback Girl.midi # 16
# Hollaback Girl.midi raised error
# Processing file  Rolling Waves.midi # 17
# Rolling Waves.midi raised error
# Processing file  Everything Sounds Like Coldplay Now.midi # 18
# Everything Sounds Like Coldplay Now.midi raised error
# Processing file  Pocketful of Sunshine.midi # 19
# Pocketful of Sunshine.midi raised error
# Processing file  Strong Enough.midi # 20
# Strong Enough.midi raised error
# Processing file  All About That Bass.midi # 21
# All About That Bass.midi raised error
# Processing file  Atemlos.midi # 22
# Atemlos.midi raised error
# Processing file  American Boy.midi # 23
# American Boy.midi raised error
# Processing file  Lips are Movin.midi # 24
# Lips are Movin.midi raised error
# Processing file  Cryin'.midi # 25
# Cryin'.midi raised error
# Processing file  Hard Times.midi # 26
# Hard Times.midi raised error
# Processing file  500 Miles.midi # 27
# 500 Miles.midi raised error
# Processing file  All of Me.midi # 28
# All of Me.midi raised error
# Processing file  Paparazzi.midi # 29
# Paparazzi.midi raised error
# Processing file  That's What I Like.midi # 30
# That's What I Like.midi raised error
# Processing file  This Love.midi # 31
# This Love.midi raised error
# Processing file  Love Me.midi # 32
# Love Me.midi raised error
# Processing file  You Came.midi # 33
# You Came.midi raised error
# Processing file  Wide Awake.midi # 34
# Wide Awake.midi raised error
# Processing file  Allentown.midi # 35
# Allentown.midi raised error
# Processing file  Hungry Like The Wolf.midi # 36
# Hungry Like The Wolf.midi raised error
# Processing file  Baby I'm Yours.midi # 37
# Baby I'm Yours.midi raised error
# Processing file  By Christmas.midi # 38
# By Christmas.midi raised error
# Processing file  Ride.midi # 39
# Ride.midi raised error
# Processing file  Closer.midi # 40
# Closer.midi raised error
# Processing file  Canned Heat.midi # 41
# Canned Heat.midi raised error
# Processing file  Baby Love.midi # 42
# Baby Love.midi raised error
# Processing file  Sunday Morning.midi # 43
# Sunday Morning.midi raised error
# Processing file  I Cry.midi # 44
# I Cry.midi raised error
# Processing file  Beautiful Life.midi # 45
# Beautiful Life.midi raised error
# Processing file  Addicted to a Memory feat Bahari.midi # 46
# Addicted to a Memory feat Bahari.midi raised error
# Processing file  The Spirit of Jazz.midi # 47
# The Spirit of Jazz.midi raised error
# Processing file  It's The Things You Do.midi # 48
# It's The Things You Do.midi raised error
# Processing file  Photograph.midi # 49
# Photograph.midi raised error
# Processing file  Fireflies.midi # 50
# Processing file  Leave Your Lover.midi # 51
# Leave Your Lover.midi raised error
# Processing file  Silver Springs.midi # 52
# Silver Springs.midi raised error
# Processing file  God Only Knows.midi # 53
# God Only Knows.midi raised error
# Processing file  Love Never Felt So Good.midi # 54
# Love Never Felt So Good.midi raised error
# Processing file  More Than A Memory.midi # 55
# More Than A Memory.midi raised error
# Processing file  La La La.midi # 56
# La La La.midi raised error
# Processing file  Be Like That.midi # 57
# Be Like That.midi raised error
# Processing file  I Believe In A Thing Called Love.midi # 58
# I Believe In A Thing Called Love.midi raised error
# Processing file  Save The Last Dance For Me.midi # 59
# Save The Last Dance For Me.midi raised error
# Processing file  Someone Like You.midi # 60
# Someone Like You.midi raised error
# Processing file  Baby-Baby-Baby.midi # 61
# Baby-Baby-Baby.midi raised error
# Processing file  Please Don't Go.midi # 62
# Please Don't Go.midi raised error
# Processing file  Shake Your Love.midi # 63
# Shake Your Love.midi raised error
# Processing file  Baby.midi # 64
# Baby.midi raised error
# Processing file  Night Changes .midi # 65
# Night Changes .midi raised error
# Processing file  What Do You Mean It's 1985.midi # 66
# What Do You Mean It's 1985.midi raised error
# Processing file  Maybe I Like It.midi # 67
# Maybe I Like It.midi raised error
# Processing file  Ribbon In The Sky.midi # 68
# Processing file  All I Have To Give.midi # 69
# All I Have To Give.midi raised error
# Processing file  Still Crazy After All These Years.midi # 70
# Still Crazy After All These Years.midi raised error
# Processing file  Sweatshirt.midi # 71
# Sweatshirt.midi raised error
# Processing file  Heavy Metal Lover.midi # 72
# Heavy Metal Lover.midi raised error
# Processing file  Trumpets.midi # 73
# Trumpets.midi raised error
# Processing file  Sukirman.midi # 74
# Sukirman.midi raised error
# Processing file  Habits - Stay High.midi # 75
# Habits - Stay High.midi raised error
# Processing file  Electricity.midi # 76
# Electricity.midi raised error
# Processing file  Moves Like Jagger.midi # 77
# Moves Like Jagger.midi raised error
# Processing file  Uptown Funk.midi # 78
# Uptown Funk.midi raised error
# Processing file  We Can't Stop.midi # 79
# We Can't Stop.midi raised error
# Processing file  Colourless Color.midi # 80
# Colourless Color.midi raised error
# Processing file  My All.midi # 81
# Processing file  In Your Eyes.midi # 82
# In Your Eyes.midi raised error
# Processing file  Back In The High Life Again.midi # 83
# Back In The High Life Again.midi raised error
# Processing file  You.midi # 84
# You.midi raised error
# Processing file  Take My Breath Away.midi # 85
# Take My Breath Away.midi raised error
# Processing file  Trojkaty i Kwadraty.midi # 86
# Trojkaty i Kwadraty.midi raised error
# Processing file  Bang Bang Bang.midi # 87
# Bang Bang Bang.midi raised error
# Processing file  High School Never Ends.midi # 88
# High School Never Ends.midi raised error
# Processing file  Best Friend.midi # 89
# Best Friend.midi raised error
# Processing file  Major Tom - Voellig Losgeloest.midi # 90
# Major Tom - Voellig Losgeloest.midi raised error
# Processing file  Green Light.midi # 91
# Green Light.midi raised error
# Processing file  Maniac.midi # 92
# Maniac.midi raised error
# Processing file  Boyfriend.midi # 93
# Boyfriend.midi raised error
# Processing file  Cleopatra's Theme.midi # 94
# Cleopatra's Theme.midi raised error
# Processing file  Satisfaction.midi # 95
# Satisfaction.midi raised error
# Processing file  Dancing Queen.midi # 96
# Dancing Queen.midi raised error
# Processing file  Just Can't Get Enough.midi # 97
# Just Can't Get Enough.midi raised error
# Processing file  3.midi # 98
# 3.midi raised error
# Processing file  Heart Of Glass.midi # 99
# Heart Of Glass.midi raised error
# Processing file  Cheap Thrills.midi # 100
# Cheap Thrills.midi raised error
# Processing file  No Milk Today.midi # 101
# No Milk Today.midi raised error
# Processing file  Saving All My Love For You.midi # 102
# Saving All My Love For You.midi raised error
# Processing file  Bailamos.midi # 103
# Bailamos.midi raised error
# Processing file  Tonight.midi # 104
# Processing file  The Voice Within.midi # 105
# The Voice Within.midi raised error
# Processing file  Kiss You.midi # 106
# Kiss You.midi raised error
# Processing file  Melt.midi # 107
# Melt.midi raised error
# Processing file  Take Me As I Am.midi # 108
# Take Me As I Am.midi raised error
# Processing file  Rock That Body.midi # 109
# Rock That Body.midi raised error
# Processing file  Postcards.midi # 110
# Postcards.midi raised error
# Processing file  Larger Than Life.midi # 111
# Larger Than Life.midi raised error
# Processing file  I'm A Slave 4 U.midi # 112
# I'm A Slave 4 U.midi raised error
# Processing file  Yesterday.midi # 113
# Yesterday.midi raised error
# Processing file  Greatest Love Of All.midi # 114
# Greatest Love Of All.midi raised error
# Processing file  Until I Die.midi # 115
# Until I Die.midi raised error
# Processing file  True Disaster.midi # 116
# True Disaster.midi raised error
# Processing file  Titanium feat Sia.midi # 117
# Titanium feat Sia.midi raised error
# Processing file  Beautiful Day.midi # 118
# Beautiful Day.midi raised error
# Processing file  Bop To The Top.midi # 119
# Bop To The Top.midi raised error
# Processing file  Few Fire 'Malo Ognya'.midi # 120
# Few Fire 'Malo Ognya'.midi raised error
# Processing file  All The Rage.midi # 121
# All The Rage.midi raised error
# Processing file  Bust A Move.midi # 122
# Processing file  Helena Beat.midi # 123
# Helena Beat.midi raised error
# Processing file  Abracadabra.midi # 124
# Abracadabra.midi raised error
# Processing file  Holler.midi # 125
# Holler.midi raised error
# Processing file  Here.midi # 126
# Here.midi raised error
# Processing file  Gimme Gimme Gimme A Man After Midnight.midi # 127
# Gimme Gimme Gimme A Man After Midnight.midi raised error
# Processing file  Lego House.midi # 128
# Lego House.midi raised error
# Processing file  Irresistible.midi # 129
# Irresistible.midi raised error
# Processing file  Sweet Dreams - Are Made of This.midi # 130
# Processing file  Excuse My Rude.midi # 131
# Excuse My Rude.midi raised error
# Processing file  When Love Takes Over ft Kelly Rowland.midi # 132
# When Love Takes Over ft Kelly Rowland.midi raised error
# Processing file  Holiday Road.midi # 133
# Holiday Road.midi raised error
# Processing file  No Scrubs.midi # 134
# Processing file  Body Work ft Tegan and Sara.midi # 135
# Body Work ft Tegan and Sara.midi raised error
# Processing file  Always Be My Baby.midi # 136
# Always Be My Baby.midi raised error
# Processing file  50 Ways to Say Goodbye.midi # 137
# 50 Ways to Say Goodbye.midi raised error
# Processing file  Karma Chameleon.midi # 138
# Karma Chameleon.midi raised error
# Processing file  All Together Now.midi # 139
# All Together Now.midi raised error
# Processing file  Such Great Heights.midi # 140
# Such Great Heights.midi raised error
# Processing file  Survivor.midi # 141
# Survivor.midi raised error
# Processing file  Glow.midi # 142
# Glow.midi raised error
# Processing file  Good Day Sunshine.midi # 143
# Good Day Sunshine.midi raised error
# Processing file  Another Day in Paradise.midi # 144
# Another Day in Paradise.midi raised error
# Processing file  See You Again.midi # 145
# Processing file  Mirrors.midi # 146
# Mirrors.midi raised error
# Processing file  Centuries.midi # 147
# Centuries.midi raised error
# Processing file  Halfway Around The World.midi # 148
# Halfway Around The World.midi raised error
# Processing file  Never Had A Dream Come True.midi # 149
# Never Had A Dream Come True.midi raised error
# Processing file  Young Turks.midi # 150
# Young Turks.midi raised error
# Processing file  Biology.midi # 151
# Biology.midi raised error
# Processing file  I Dont Wanna Live Forever.midi # 152
# I Dont Wanna Live Forever.midi raised error
# Processing file  Roses ft ROZES.midi # 153
# Roses ft ROZES.midi raised error
# Processing file  GUY.midi # 154
# GUY.midi raised error
# Processing file  Don't Stop Me Now.midi # 155
# Don't Stop Me Now.midi raised error
# Processing file  Once In A Lifetime.midi # 156
# Once In A Lifetime.midi raised error
# Processing file  Happy.midi # 157
# Happy.midi raised error
# Processing file  Hanging Tree - Rebel Remix.midi # 158
# Hanging Tree - Rebel Remix.midi raised error
# Processing file  Popular Song ft Ariana Grande.midi # 159
# Popular Song ft Ariana Grande.midi raised error
# Processing file  Best Of My Love.midi # 160
# Best Of My Love.midi raised error
# Processing file  Divine Sorrow.midi # 161
# Divine Sorrow.midi raised error
# Processing file  Hold Me Tight.midi # 162
# Hold Me Tight.midi raised error
# Processing file  Truly Madly Deeply.midi # 163
# Truly Madly Deeply.midi raised error
# Processing file  Lost In Your Eyes.midi # 164
# Lost In Your Eyes.midi raised error
# Processing file  Gasoline.midi # 165
# Gasoline.midi raised error
# Processing file  Kick Drum Heart.midi # 166
# Kick Drum Heart.midi raised error
# Processing file  Clarity Vicetone Remix .midi # 167
# Clarity Vicetone Remix .midi raised error
# Processing file  Hips Don't Lie ft Wyclef Jean.midi # 168
# Hips Don't Lie ft Wyclef Jean.midi raised error
# Processing file  Piece of Me.midi # 169
# Piece of Me.midi raised error
# Processing file  Destroy Everything You Touch.midi # 170
# Destroy Everything You Touch.midi raised error
# Processing file  Circus.midi # 171
# Circus.midi raised error
# Processing file  Can't Stop Singing.midi # 172
# Can't Stop Singing.midi raised error
# Processing file  W Dobra Strone.midi # 173
# W Dobra Strone.midi raised error
# Processing file  Mamma Mia.midi # 174
# Mamma Mia.midi raised error
# Processing file  Smoke Rings in the Dark.midi # 175
# Smoke Rings in the Dark.midi raised error
# Processing file  I Write the Songs.midi # 176
# I Write the Songs.midi raised error
# Processing file  Moskau.midi # 177
# Moskau.midi raised error
# Processing file  Michelle.midi # 178
# Michelle.midi raised error
# Processing file  Fighter.midi # 179
# Fighter.midi raised error
# Processing file  Higher Love.midi # 180
# Higher Love.midi raised error
# Processing file  Honey.midi # 181
# Honey.midi raised error
# Processing file  Eh Eh.midi # 182
# Eh Eh.midi raised error
# Processing file  1 2 3 4.midi # 183
# 1 2 3 4.midi raised error
# Processing file  Miracle.midi # 184
# Miracle.midi raised error
# Processing file  Loca ft Dizzee Rascal.midi # 185
# Loca ft Dizzee Rascal.midi raised error
# Processing file  Four Chord Songs.midi # 186
# Processing file  My Sharona.midi # 187
# My Sharona.midi raised error
# Processing file  Fiona Coyne.midi # 188
# Fiona Coyne.midi raised error
# Processing file  Mama.midi # 189
# Mama.midi raised error
# Processing file  Chasing Pavements.midi # 190
# Chasing Pavements.midi raised error
# Processing file  The Gummy Bear Song.midi # 191
# The Gummy Bear Song.midi raised error
# Processing file  Elastic Heart.midi # 192
# Elastic Heart.midi raised error
# Processing file  No No No Part 2.midi # 193
# No No No Part 2.midi raised error
# Processing file  Please Please Me.midi # 194
# Please Please Me.midi raised error
# Processing file  Bed Of Lies.midi # 195
# Bed Of Lies.midi raised error
# Processing file  Bright.midi # 196
# Bright.midi raised error
# Processing file  Wildest Dreams.midi # 197
# Wildest Dreams.midi raised error
# Processing file  Diamonds.midi # 198
# Diamonds.midi raised error
# Processing file  Other Side Of Love.midi # 199
# Other Side Of Love.midi raised error
# Processing file  Satellite.midi # 200
# Satellite.midi raised error
# Processing file  I Believe I Can Fly.midi # 201
# I Believe I Can Fly.midi raised error
# Processing file  Still Alive-Mirror's Edge OST.midi # 202
# Still Alive-Mirror's Edge OST.midi raised error
# Processing file  Hot N Cold.midi # 203
# Hot N Cold.midi raised error
# Processing file  Ebb and Flow.midi # 204
# Ebb and Flow.midi raised error
# Processing file  All I Need.midi # 205
# All I Need.midi raised error
# Processing file  Nothin' On You.midi # 206
# Nothin' On You.midi raised error
# Processing file  Wont Look Back.midi # 207
# Wont Look Back.midi raised error
# Processing file  And I Love Her.midi # 208
# And I Love Her.midi raised error
# Processing file  Llama In My Living Room.midi # 209
# Llama In My Living Room.midi raised error
# Processing file  Boy Problems.midi # 210
# Boy Problems.midi raised error
# Processing file  Dia Melihatku.midi # 211
# Dia Melihatku.midi raised error
# Processing file  Flashlight.midi # 212
# Flashlight.midi raised error
# Processing file  Stitches.midi # 213
# Stitches.midi raised error
# Processing file  ET.midi # 214
# ET.midi raised error
# Processing file  We Are The Sea.midi # 215
# We Are The Sea.midi raised error
# Processing file  Don't You Forget.midi # 216
# Don't You Forget.midi raised error
# Processing file  Oliver's Army.midi # 217
# Oliver's Army.midi raised error
# Processing file  Wrecking Ball.midi # 218
# Wrecking Ball.midi raised error
# Processing file  Bossman.midi # 219
# Bossman.midi raised error
# Processing file  Little Lies.midi # 220
# Little Lies.midi raised error
# Processing file  Three Stars No Match.midi # 221
# Three Stars No Match.midi raised error
# Processing file  A Contre-Courant.midi # 222
# A Contre-Courant.midi raised error
# Processing file  We've Got It Goin' On.midi # 223
# We've Got It Goin' On.midi raised error
# Processing file  Sing The Changes.midi # 224
# Sing The Changes.midi raised error
# Processing file  Paris.midi # 225
# Paris.midi raised error
# Processing file  Lights.midi # 226
# Lights.midi raised error
# Processing file  Osama Obama.midi # 227
# Osama Obama.midi raised error
# Processing file  Ordinary World.midi # 228
# Ordinary World.midi raised error
# Processing file  Paparazzi Acoustic.midi # 229
# Paparazzi Acoustic.midi raised error
# Processing file  Stick to the Status Quo.midi # 230
# Stick to the Status Quo.midi raised error
# Processing file  Shots - Broiler Remix.midi # 231
# Shots - Broiler Remix.midi raised error
# Processing file  Gimme More.midi # 232
# Gimme More.midi raised error
# Processing file  Valleri.midi # 233
# Valleri.midi raised error
# Processing file  Dragostea Din Tei.midi # 234
# Dragostea Din Tei.midi raised error
# Processing file  Feeling Electric.midi # 235
# Feeling Electric.midi raised error
# Processing file  Whistle.midi # 236
# Whistle.midi raised error
# Processing file  Vacation.midi # 237
# Vacation.midi raised error
# Processing file  Tearin Up My Heart.midi # 238
# Tearin Up My Heart.midi raised error
# Processing file  Telephone.midi # 239
# Telephone.midi raised error
# Processing file  Wild Ones.midi # 240
# Wild Ones.midi raised error
# Processing file  Ready For The Weekend.midi # 241
# Ready For The Weekend.midi raised error
# Processing file  Ready For It.midi # 242
# Ready For It.midi raised error
# Processing file  Chasing The Sun.midi # 243
# Chasing The Sun.midi raised error
# Processing file  Last Night.midi # 244
# Last Night.midi raised error
# Processing file  We Are Never Ever Getting Back Together.midi # 245
# We Are Never Ever Getting Back Together.midi raised error
# Processing file  Viva Forever.midi # 246
# Processing file  Best Day Of My Life.midi # 247
# Best Day Of My Life.midi raised error
# Processing file  Animals.midi # 248
# Animals.midi raised error
# Processing file  CAKE BY THE OCEAN.midi # 249
# CAKE BY THE OCEAN.midi raised error
# Processing file  2 Hearts.midi # 250
# 2 Hearts.midi raised error
# Processing file  Papercut feat Troye Sivan.midi # 251
# Papercut feat Troye Sivan.midi raised error
# Processing file  Mean Mr Mustard.midi # 252
# Mean Mr Mustard.midi raised error
# Processing file  Catch.midi # 253
# Catch.midi raised error
# Processing file  A Thousand Miles.midi # 254
# A Thousand Miles.midi raised error
# Processing file  Isn't She Lovely.midi # 255
# Isn't She Lovely.midi raised error
# Processing file  New Age.midi # 256
# New Age.midi raised error
# Processing file  My Way Is My Decision.midi # 257
# My Way Is My Decision.midi raised error
# Processing file  Foolish Beat.midi # 258
# Foolish Beat.midi raised error
# Processing file  Starships.midi # 259
# Starships.midi raised error
# Processing file  Thnks fr th Mmrs.midi # 260
# Thnks fr th Mmrs.midi raised error
# Processing file  Carried Away.midi # 261
# Carried Away.midi raised error
# Processing file  Get Outta My Way.midi # 262
# Get Outta My Way.midi raised error
# Processing file  Let Me Love You.midi # 263
# Processing file  I'm Like A Lawyer.midi # 264
# I'm Like A Lawyer.midi raised error
# Processing file  Stop In The Name Of Love.midi # 265
# Stop In The Name Of Love.midi raised error
# Processing file  Bizarre Love Triangle.midi # 266
# Bizarre Love Triangle.midi raised error
# Processing file  Warrior.midi # 267
# Warrior.midi raised error
# Processing file  Master of Disguise.midi # 268
# Master of Disguise.midi raised error
# Processing file  Jockel der Gartenteichspringbrunnen.midi # 269
# Jockel der Gartenteichspringbrunnen.midi raised error
# Processing file  Accidently Kelly Street.midi # 270
# Accidently Kelly Street.midi raised error
# Processing file  Eternal Flame.midi # 271
# Eternal Flame.midi raised error
# Processing file  Joanne.midi # 272
# Joanne.midi raised error
# Processing file  Without You - New Version.midi # 273
# Without You - New Version.midi raised error
# Processing file  Fade Away.midi # 274
# Fade Away.midi raised error
# Processing file  You Can Call Me Al.midi # 275
# You Can Call Me Al.midi raised error
# Processing file  Baby One More Time.midi # 276
# Baby One More Time.midi raised error
# Processing file  Everybody.midi # 277
# Everybody.midi raised error
# Processing file  Tiny Dancer.midi # 278
# Tiny Dancer.midi raised error
# Processing file  Time.midi # 279
# Time.midi raised error
# Processing file  Rehab.midi # 280
# Rehab.midi raised error
# Processing file  Colour My World.midi # 281
# Colour My World.midi raised error
# Processing file  Pompeii.midi # 282
# Pompeii.midi raised error
# Processing file  Free The Animal.midi # 283
# Free The Animal.midi raised error
# Processing file  Hello.midi # 284
# Hello.midi raised error
# Processing file  Fight For This Love.midi # 285
# Fight For This Love.midi raised error
# Processing file  Waterfalls.midi # 286
# Waterfalls.midi raised error
# Processing file  Move Your Feet.midi # 287
# Move Your Feet.midi raised error
# Processing file  Stars Are Blind.midi # 288
# Stars Are Blind.midi raised error
# Processing file  Give Me Love.midi # 289
# Give Me Love.midi raised error
# Processing file  Stuck in a Moment You Can't Get Out Of.midi # 290
# Stuck in a Moment You Can't Get Out Of.midi raised error
# Processing file  Hide And Seek.midi # 291
# Hide And Seek.midi raised error
# Processing file  Ugly Heart .midi # 292
# Ugly Heart .midi raised error
# Processing file  Sky Fits Heaven.midi # 293
# Sky Fits Heaven.midi raised error
# Processing file  What's In It For Me.midi # 294
# What's In It For Me.midi raised error
# Processing file  Our House.midi # 295
# Our House.midi raised error
# Processing file  Paradise.midi # 296
# Processing file  Pre Payphone.midi # 297
# Pre Payphone.midi raised error
# Processing file  Come Clean.midi # 298
# Come Clean.midi raised error
# Processing file  Ever Ever After.midi # 299
# Ever Ever After.midi raised error
# Processing file  Crazy Little Thing Called Love.midi # 300
# Crazy Little Thing Called Love.midi raised error
# Processing file  Strangelove.midi # 301
# Strangelove.midi raised error
# Processing file  Come Into My World.midi # 302
# Come Into My World.midi raised error
# Processing file  Holding Out For A Hero.midi # 303
# Holding Out For A Hero.midi raised error
# Processing file  Wuthering Heights.midi # 304
# Wuthering Heights.midi raised error
# Processing file  Hat 2 Da Back.midi # 305
# Hat 2 Da Back.midi raised error
# Processing file  Lovefool.midi # 306
# Lovefool.midi raised error
# Processing file  Turn Me On.midi # 307
# Turn Me On.midi raised error
# Processing file  If I Needed Someone.midi # 308
# If I Needed Someone.midi raised error
# Processing file  Smile.midi # 309
# Smile.midi raised error
# Processing file  Jumpin Jumpin.midi # 310
# Jumpin Jumpin.midi raised error
# Processing file  Lush Life.midi # 311
# Lush Life.midi raised error
# Processing file  Back In Time.midi # 312
# Back In Time.midi raised error
# Processing file  I'm Not the Only One.midi # 313
# I'm Not the Only One.midi raised error
# Processing file  Make Me Like You.midi # 314
# Make Me Like You.midi raised error
# Processing file  Call Your Girlfriend.midi # 315
# Call Your Girlfriend.midi raised error
# Processing file  Colors.midi # 316
# Colors.midi raised error
# Processing file  Can't Remember To Forget You ft Rihanna.midi # 317
# Can't Remember To Forget You ft Rihanna.midi raised error
# Processing file  Battlefield.midi # 318
# Battlefield.midi raised error
# Processing file  Say My Name.midi # 319
# Say My Name.midi raised error
# Processing file  Levels.midi # 320
# Levels.midi raised error
# Processing file  Stay - I Missed You.midi # 321
# Stay - I Missed You.midi raised error
# Processing file  Born to make you happy.midi # 322
# Born to make you happy.midi raised error
# Processing file  The Look.midi # 323
# The Look.midi raised error
# Processing file  Overnite.midi # 324
# Overnite.midi raised error
# Processing file  Together Again.midi # 325
# Together Again.midi raised error
# Processing file  My House.midi # 326
# My House.midi raised error
# Processing file  No Air.midi # 327
# No Air.midi raised error
# Processing file  Too Much.midi # 328
# Too Much.midi raised error
# Processing file  Keeps Gettin' Better.midi # 329
# Keeps Gettin' Better.midi raised error
# Processing file  Livin La Vida Loca.midi # 330
# Livin La Vida Loca.midi raised error
# Processing file  Can't Stop Dancin'.midi # 331
# Can't Stop Dancin'.midi raised error
# Processing file  One of Us.midi # 332
# One of Us.midi raised error
# Processing file  Just Like Heaven.midi # 333
# Just Like Heaven.midi raised error
# Processing file  Vision of Love.midi # 334
# Processing file  Sail.midi # 335
# Sail.midi raised error
# Processing file  Already Gone.midi # 336
# Already Gone.midi raised error
# Processing file  Buttons.midi # 337
# Buttons.midi raised error
# Processing file  Feel So Close.midi # 338
# Feel So Close.midi raised error
# Processing file  I Was Gonna Cancel.midi # 339
# I Was Gonna Cancel.midi raised error
# Processing file  Dressin' Up.midi # 340
# Dressin' Up.midi raised error
# Processing file  Swim.midi # 341
# Swim.midi raised error
# Processing file  Tragedy.midi # 342
# Processing file  Woman In Love.midi # 343
# Woman In Love.midi raised error
# Processing file  Devil Pray.midi # 344
# Devil Pray.midi raised error
# Processing file  Zui xuan min zu feng.midi # 345
# Zui xuan min zu feng.midi raised error
# Processing file  Party Rock Anthem.midi # 346
# Party Rock Anthem.midi raised error
# Processing file  Fancy.midi # 347
# Fancy.midi raised error
# Processing file  Always.midi # 348
# Always.midi raised error
# Processing file  Dear Prudence.midi # 349
# Dear Prudence.midi raised error
# Processing file  Electric Kiss.midi # 350
# Electric Kiss.midi raised error
# Processing file  Whenever Wherever.midi # 351
# Whenever Wherever.midi raised error
# Processing file  So Happy I Could Die.midi # 352
# So Happy I Could Die.midi raised error
# Processing file  Ayo Technology.midi # 353
# Ayo Technology.midi raised error
# Processing file  You've Changed.midi # 354
# You've Changed.midi raised error
# Processing file  Asereje.midi # 355
# Asereje.midi raised error
# Processing file  The Sun Always Shines On TV.midi # 356
# The Sun Always Shines On TV.midi raised error
# Processing file  On My Mind.midi # 357
# On My Mind.midi raised error
# Processing file  Night Fever.midi # 358
# Night Fever.midi raised error
# Processing file  Senbonzakura.midi # 359
# Senbonzakura.midi raised error
# Processing file  Straight Up.midi # 360
# Straight Up.midi raised error
# Processing file  Stay The Night.midi # 361
# Stay The Night.midi raised error
# Processing file  Mr Blue Sky.midi # 362
# Mr Blue Sky.midi raised error
# Processing file  While I'm Still Young.midi # 363
# While I'm Still Young.midi raised error
# Processing file  Sheezus.midi # 364
# Sheezus.midi raised error
# Processing file  Bounce feat Kelis.midi # 365
# Bounce feat Kelis.midi raised error
# Processing file  Jenny From The Block.midi # 366
# Jenny From The Block.midi raised error
# Processing file  Team.midi # 367
# Team.midi raised error
# Processing file  Brand New Kind of Blue.midi # 368
# Brand New Kind of Blue.midi raised error
# Processing file  I Saw The Sign.midi # 369
# I Saw The Sign.midi raised error
# Processing file  Climbing Walls.midi # 370
# Climbing Walls.midi raised error
# Processing file  Just Give Me A Reason.midi # 371
# Just Give Me A Reason.midi raised error
# Processing file  Super Bass.midi # 372
# Super Bass.midi raised error
# Processing file  Never Ever ft Susanne Sundfor.midi # 373
# Never Ever ft Susanne Sundfor.midi raised error
# Processing file  Into The Groove.midi # 374
# Into The Groove.midi raised error
# Processing file  Black or White.midi # 375
# Black or White.midi raised error
# Processing file  Air Balloon.midi # 376
# Air Balloon.midi raised error
# Processing file  If I Go.midi # 377
# If I Go.midi raised error
# Processing file  Only Girl In The World.midi # 378
# Only Girl In The World.midi raised error
# Processing file  Love Song.midi # 379
# Love Song.midi raised error
# Processing file  Locked Out Of Heaven.midi # 380
# Locked Out Of Heaven.midi raised error
# Processing file  Run.midi # 381
# Run.midi raised error
# Processing file  Built This Pool.midi # 382
# Built This Pool.midi raised error
# Processing file  I Don't Care.midi # 383
# I Don't Care.midi raised error
# Processing file  Stop.midi # 384
# Stop.midi raised error
# Processing file  Into You.midi # 385
# Into You.midi raised error
# Processing file  Who Do You Think You Are.midi # 386
# Who Do You Think You Are.midi raised error
# Processing file  Masterpiece.midi # 387
# Masterpiece.midi raised error
# Processing file  Badz Duzy.midi # 388
# Badz Duzy.midi raised error
# Processing file  Out Of The Blue.midi # 389
# Out Of The Blue.midi raised error
# Processing file  El Perdon.midi # 390
# El Perdon.midi raised error
# Processing file  S and M.midi # 391
# S and M.midi raised error
# Processing file  Perfect Way.midi # 392
# Perfect Way.midi raised error
# Processing file  Yellow Brick Road.midi # 393
# Yellow Brick Road.midi raised error
# Processing file  Perry Como.midi # 394
# Perry Como.midi raised error
# Processing file  You Da One.midi # 395
# You Da One.midi raised error
# Processing file  I Feel it Coming ft Daft Punk.midi # 396
# I Feel it Coming ft Daft Punk.midi raised error
# Processing file  Barbara Ann.midi # 397
# Barbara Ann.midi raised error
# Processing file  Give Me Everything.midi # 398
# Give Me Everything.midi raised error
# Processing file  Sometime In The Morning.midi # 399
# Sometime In The Morning.midi raised error
# Processing file  Black and White.midi # 400
# Black and White.midi raised error
# Processing file  Snow -Hey Oh-.midi # 401
# Snow -Hey Oh-.midi raised error
# Processing file  It's Not Right But It's Okay - Remix.midi # 402
# It's Not Right But It's Okay - Remix.midi raised error
# Processing file  Full Disclosure - Steven Universe.midi # 403
# Full Disclosure - Steven Universe.midi raised error
# Processing file  Where Are U Now feat Justin Bieber.midi # 404
# Where Are U Now feat Justin Bieber.midi raised error
# Processing file  Every Time We Touch.midi # 405
# Every Time We Touch.midi raised error
# Processing file  Diggin' On You.midi # 406
# Diggin' On You.midi raised error
# Processing file  Set Fire to the Rain.midi # 407
# Set Fire to the Rain.midi raised error
# Processing file  Daughters.midi # 408
# Daughters.midi raised error
# Processing file  Shower.midi # 409
# Shower.midi raised error
# Processing file  She's Not the End of the World.midi # 410
# She's Not the End of the World.midi raised error
# Processing file  Extraordinary.midi # 411
# Extraordinary.midi raised error
# Processing file  SalahBeli.midi # 412
# SalahBeli.midi raised error
# Processing file  Like A Virgin.midi # 413
# Like A Virgin.midi raised error
# Processing file  The Sweet Escape.midi # 414
# The Sweet Escape.midi raised error
# Processing file  We Are Number One.midi # 415
# We Are Number One.midi raised error
# Processing file  Halo.midi # 416
# Halo.midi raised error
# Processing file  More More More.midi # 417
# More More More.midi raised error
# Processing file  One Word.midi # 418
# One Word.midi raised error
# Processing file  Give It To Me.midi # 419
# Give It To Me.midi raised error
# Processing file  Nobody Love.midi # 420
# Nobody Love.midi raised error
# Processing file  Sorry.midi # 421
# Sorry.midi raised error
# Processing file  Jack City Bich.midi # 422
# Jack City Bich.midi raised error
# Processing file  Peanut Butter Jelly.midi # 423
# Peanut Butter Jelly.midi raised error
# Processing file  I Just Died In Your Arms.midi # 424
# I Just Died In Your Arms.midi raised error
# Processing file  I'm Still Here.midi # 425
# I'm Still Here.midi raised error
# Processing file  Dark Paradise.midi # 426
# Dark Paradise.midi raised error
# Processing file  Oh Darling.midi # 427
# Oh Darling.midi raised error
# Processing file  Girls on the Beach.midi # 428
# Girls on the Beach.midi raised error
# Processing file  I Didn't Mean To Turn You On.midi # 429
# I Didn't Mean To Turn You On.midi raised error
# Processing file  Durham Town.midi # 430
# Durham Town.midi raised error
# Processing file  Boom Clap.midi # 431
# Boom Clap.midi raised error
# Processing file  Archie Marry Me.midi # 432
# Archie Marry Me.midi raised error
# Processing file  Starboy.midi # 433
# Starboy.midi raised error
# Processing file  Around The World.midi # 434
# Around The World.midi raised error
# Processing file  Los Angeles.midi # 435
# Los Angeles.midi raised error
# Processing file  In My Arms.midi # 436
# In My Arms.midi raised error
# Processing file  Heaven.midi # 437
# Heaven.midi raised error
# Processing file  1973.midi # 438
# 1973.midi raised error
# Processing file  She Wolf.midi # 439
# She Wolf.midi raised error
# Processing file  Big Girls Don't Cry.midi # 440
# Big Girls Don't Cry.midi raised error
# Processing file  Nine Million Bicycles.midi # 441
# Nine Million Bicycles.midi raised error
# Processing file  Chandelier-.midi # 442
# Chandelier-.midi raised error
# Processing file  Love Me Again.midi # 443
# Love Me Again.midi raised error
# Processing file  Don't.midi # 444
# Don't.midi raised error
# Processing file  Scatman's World.midi # 445
# Scatman's World.midi raised error
# Processing file  Sittin' Up In My Room.midi # 446
# Sittin' Up In My Room.midi raised error
# Processing file  One Last Time.midi # 447
# One Last Time.midi raised error
# Processing file  Young Forever.midi # 448
# Young Forever.midi raised error
# Processing file  I Can't Explain.midi # 449
# I Can't Explain.midi raised error
# Processing file  Liability.midi # 450
# Liability.midi raised error
# Processing file  Blank Space.midi # 451
# Blank Space.midi raised error
# Processing file  Copenhagen.midi # 452
# Copenhagen.midi raised error
# Processing file  That Thing You Do.midi # 453
# Processing file  You And I.midi # 454
# You And I.midi raised error
# Processing file  Tripping.midi # 455
# Tripping.midi raised error
# Processing file  Don't You Want Me.midi # 456
# Don't You Want Me.midi raised error
# Processing file  Nice Day.midi # 457
# Nice Day.midi raised error
# Processing file  I Choose You.midi # 458
# I Choose You.midi raised error
# Processing file  Hinoito Rinne no GEMINI.midi # 459
# Hinoito Rinne no GEMINI.midi raised error
# Processing file  Sign of the Times.midi # 460
# Sign of the Times.midi raised error
# Processing file  The Night Is Still Young.midi # 461
# The Night Is Still Young.midi raised error
# Processing file  Everlasting Love.midi # 462
# Everlasting Love.midi raised error
# Processing file  Touch My Hand.midi # 463
# Processing file  Hardware Store.midi # 464
# Hardware Store.midi raised error
# Processing file  Gotta Tell You.midi # 465
# Gotta Tell You.midi raised error
# Processing file  Powerful ft Ellie Goulding and Tarrus Riley.midi # 466
# Powerful ft Ellie Goulding and Tarrus Riley.midi raised error
# Processing file  You Can Dance.midi # 467
# You Can Dance.midi raised error
# Processing file  Put Your Records On.midi # 468
# Put Your Records On.midi raised error
# Processing file  Is This The Way To Amarillo.midi # 469
# Is This The Way To Amarillo.midi raised error
# Processing file  Chained To The Rhythm.midi # 470
# Chained To The Rhythm.midi raised error
# Processing file  Right Here.midi # 471
# Right Here.midi raised error
# Processing file  Quit Playing Games With My Heart.midi # 472
# Quit Playing Games With My Heart.midi raised error
# Processing file  Creep.midi # 473
# Creep.midi raised error
# Processing file  If We Ever Meet Again.midi # 474
# Processing file  Snowblind feat Tasha Baxter.midi # 475
# Snowblind feat Tasha Baxter.midi raised error
# Processing file  Livin' On The Run.midi # 476
# Livin' On The Run.midi raised error
# Processing file  Price Tag.midi # 477
# Price Tag.midi raised error
# Processing file  We Didn't Start The Fire.midi # 478
# We Didn't Start The Fire.midi raised error
# Processing file  Maps.midi # 479
# Maps.midi raised error
# Processing file  New Romantics.midi # 480
# New Romantics.midi raised error
# Feel The Love.midi raised error
# Processing file  So Long.midi # 481
# So Long.midi raised error
# Processing file  He Won't Go.midi # 482
# He Won't Go.midi raised error
# Processing file  LA Hallucinations.midi # 483
# LA Hallucinations.midi raised error
# Processing file  One Call Away.midi # 484
# One Call Away.midi raised error
# Processing file  The Anthem.midi # 485
# The Anthem.midi raised error
# Processing file  Walk Away.midi # 486
# Walk Away.midi raised error
# Processing file  Painful Like.midi # 487
# Painful Like.midi raised error
# Processing file  Shark Attack.midi # 488
# Shark Attack.midi raised error
# Processing file  Erase-Rewind.midi # 489
# Erase-Rewind.midi raised error
# Processing file  Stay With Me.midi # 490
# Stay With Me.midi raised error
# Processing file  The Only Exception.midi # 491
# The Only Exception.midi raised error
# Processing file  Ghost.midi # 492
# Ghost.midi raised error
# Processing file  Catch My Breath.midi # 493
# Catch My Breath.midi raised error
# Processing file  Livin Thing.midi # 494
# Livin Thing.midi raised error
# Processing file  Liquid Love.midi # 495
# Liquid Love.midi raised error
# Processing file  Child's Play.midi # 496
# Child's Play.midi raised error
# Processing file  Daniel.midi # 497
# Daniel.midi raised error
# Processing file  Bills Bills Bills.midi # 498
# Processing file  The Stars.midi # 499
# The Stars.midi raised error
# Processing file  Love Letter To Japan.midi # 500
# Love Letter To Japan.midi raised error
# Processing file  Las De La Intuicion.midi # 501
# Las De La Intuicion.midi raised error
# Processing file  Hey Ya.midi # 502
# Hey Ya.midi raised error
# Processing file  Rude.midi # 503
# Rude.midi raised error
# Processing file  Good Time.midi # 504
# Good Time.midi raised error
# Processing file  Lipgloss ft Cupcakke.midi # 505
# Lipgloss ft Cupcakke.midi raised error
# Processing file  Payphone.midi # 506
# Payphone.midi raised error
# Processing file  Goodbye.midi # 507
# Goodbye.midi raised error
# Processing file  Don't Know Why.midi # 508
# Don't Know Why.midi raised error
# Processing file  Secret.midi # 509
# Secret.midi raised error
# Processing file  Nothing Really Matters.midi # 510
# Nothing Really Matters.midi raised error
# Processing file  A Public Affair.midi # 511
# A Public Affair.midi raised error
# Processing file  A Year Without Rain.midi # 512
# A Year Without Rain.midi raised error
# Processing file  22.midi # 513
# 22.midi raised error
# Processing file  Fanny Be Tender With My Love.midi # 514
# Fanny Be Tender With My Love.midi raised error
# Processing file  Brown Eyes.midi # 515
# Brown Eyes.midi raised error
# Processing file  Tag You're It.midi # 516
# Tag You're It.midi raised error
# Processing file  Take Pills.midi # 517
# Take Pills.midi raised error
# Processing file  I'll Be There For You.midi # 518
# I'll Be There For You.midi raised error
# Processing file  Independent Women Part 1.midi # 519
# Independent Women Part 1.midi raised error
# Processing file  You Learn.midi # 520
# You Learn.midi raised error
# Processing file  Unwritten.midi # 521
# Unwritten.midi raised error
# Processing file  Break Your Heart.midi # 522
# Break Your Heart.midi raised error
# Processing file  Wonder.midi # 523
# Wonder.midi raised error
# Processing file  All That She Wants.midi # 524
# All That She Wants.midi raised error
# Processing file  I Wanna Be With You.midi # 525
# I Wanna Be With You.midi raised error
# Processing file  The Business of Emotion ft White Sea.midi # 526
# The Business of Emotion ft White Sea.midi raised error
# Processing file  New Man.midi # 527
# New Man.midi raised error
# Processing file  Kill The Director.midi # 528
# Kill The Director.midi raised error
# Processing file  Open Your Heart.midi # 529
# Open Your Heart.midi raised error
# Processing file  Moi Lolita.midi # 530
# Moi Lolita.midi raised error
# Processing file  Sweet Lovin.midi # 531
# Sweet Lovin.midi raised error
# Processing file  Bootylicious.midi # 532
# Bootylicious.midi raised error
# Processing file  Barbie Girl.midi # 533
# Barbie Girl.midi raised error
# Processing file  430 am.midi # 534
# 430 am.midi raised error
# Processing file  Hold On We're Going Home.midi # 535
# Hold On We're Going Home.midi raised error
# Processing file  Madness.midi # 536
# Madness.midi raised error
# Processing file  You're Driving Me Crazy.midi # 537
# You're Driving Me Crazy.midi raised error
# Processing file  Clarity.midi # 538
# Clarity.midi raised error
# Processing file  Love Machine.midi # 539
# Love Machine.midi raised error
# Processing file  Double Vision.midi # 540
# Double Vision.midi raised error
# Processing file  I Saw Her Again.midi # 541
# I Saw Her Again.midi raised error
# Processing file  Coming Around Again.midi # 542
# Coming Around Again.midi raised error
# Processing file  On The Floor.midi # 543
# On The Floor.midi raised error
# Processing file  Sweet Nothing.midi # 544
# Sweet Nothing.midi raised error
# Processing file  Begin Again.midi # 545
# Begin Again.midi raised error
# Processing file  Save Me.midi # 546
# Save Me.midi raised error
# Processing file  Friend Shitai.midi # 547
# Friend Shitai.midi raised error
# Processing file  Hideaway.midi # 548
# Hideaway.midi raised error
# Processing file  Cool Girl.midi # 549
# Cool Girl.midi raised error
# Processing file  Me And The Rhythm.midi # 550
# Me And The Rhythm.midi raised error
# Processing file  Strong.midi # 551
# Strong.midi raised error
# Processing file  Home.midi # 552
# Home.midi raised error
# Processing file  Whatcha Say.midi # 553
# Whatcha Say.midi raised error
# Processing file  Va Va Voom.midi # 554
# Va Va Voom.midi raised error
# Processing file  Don't Let Me Get Me.midi # 555
# Don't Let Me Get Me.midi raised error
# Processing file  Kiss It Better.midi # 556
# Kiss It Better.midi raised error
# Processing file  It's Your Move.midi # 557
# It's Your Move.midi raised error
# Processing file  Over My Head - Cable Car.midi # 558
# Over My Head - Cable Car.midi raised error
# Processing file  Chocolate.midi # 559
# Chocolate.midi raised error
# Processing file  My Blood.midi # 560
# My Blood.midi raised error
# Processing file  Help.midi # 561
# Help.midi raised error
# Processing file  Hymn For The Weekend.midi # 562
# Hymn For The Weekend.midi raised error
# Processing file  Hand On Your Heart.midi # 563
# Hand On Your Heart.midi raised error
# Processing file  Talking Body.midi # 564
# Talking Body.midi raised error
# Processing file  Cellophane.midi # 565
# Cellophane.midi raised error
# Processing file  Heart Attack.midi # 566
# Heart Attack.midi raised error
# Processing file  The Lady Is A Vamp.midi # 567
# The Lady Is A Vamp.midi raised error
# Processing file  I Got You.midi # 568
# I Got You.midi raised error
# Processing file  Complicated.midi # 569
# Complicated.midi raised error
# Processing file  Cruel Summer.midi # 570
# Cruel Summer.midi raised error
# Processing file  Everything You Know Is Wrong.midi # 571
# Everything You Know Is Wrong.midi raised error
# Processing file  Lemon Tree.midi # 572
# Lemon Tree.midi raised error
# Processing file  NO.midi # 573
# NO.midi raised error
# Processing file  Nothing In This World.midi # 574
# Nothing In This World.midi raised error
# Processing file  I'll Remember.midi # 575
# I'll Remember.midi raised error
# Processing file  Cherry Wine.midi # 576
# Cherry Wine.midi raised error
# Processing file  The Show.midi # 577
# The Show.midi raised error
# Processing file  Rolling In The Deep.midi # 578
# Rolling In The Deep.midi raised error
# Processing file  Pompeii - Audien Remix.midi # 579
# Pompeii - Audien Remix.midi raised error
# Processing file  Radioactive.midi # 580
# Radioactive.midi raised error
# Processing file  Lay All Your Love On Me.midi # 581
# Lay All Your Love On Me.midi raised error
# Processing file  Warning Call.midi # 582
# Warning Call.midi raised error
# Processing file  Ocean Drive.midi # 583
# Ocean Drive.midi raised error
# Processing file  Dominique.midi # 584
# Dominique.midi raised error
# Processing file  Nobody Does It Better.midi # 585
# Nobody Does It Better.midi raised error
# Processing file  Demons.midi # 586
# Demons.midi raised error
# Processing file  Find Our Way ft Crystal Castagnazzi.midi # 587
# Find Our Way ft Crystal Castagnazzi.midi raised error
# Processing file  Beat It.midi # 588
# Beat It.midi raised error
# Processing file  G4L.midi # 589
# G4L.midi raised error
# Processing file  Because We Want To.midi # 590
# Because We Want To.midi raised error
# Processing file  Ship To Wreck.midi # 591
# Ship To Wreck.midi raised error
# Processing file  Bachelorette.midi # 592
# Bachelorette.midi raised error
# Processing file  Umbrella.midi # 593
# Umbrella.midi raised error
# Processing file  Long Train Runnin'.midi # 594
# Long Train Runnin'.midi raised error
# Processing file  Break Free feat - Ariana Grande.midi # 595
# Break Free feat - Ariana Grande.midi raised error
# Processing file  Thank You.midi # 596
# Thank You.midi raised error
# Processing file  Cool Kids.midi # 597
# Cool Kids.midi raised error
# Processing file  I Kissed A Girl.midi # 598
# I Kissed A Girl.midi raised error
# Processing file  It's a Sin.midi # 599
# It's a Sin.midi raised error
# Processing file  Try Again.midi # 600
# Try Again.midi raised error
# Processing file  We Go Oh.midi # 601
# We Go Oh.midi raised error
# Processing file  Stressed Out.midi # 602
# Stressed Out.midi raised error
# Processing file  Waking Up In Vegas.midi # 603
# Waking Up In Vegas.midi raised error
# Processing file  You Drive Me Crazy.midi # 604
# You Drive Me Crazy.midi raised error
# Processing file  Jealous.midi # 605
# Jealous.midi raised error
# Processing file  Hung Up.midi # 606
# Hung Up.midi raised error
# Processing file  Iris.midi # 607
# Iris.midi raised error
# Processing file  Sex Bomb.midi # 608
# Sex Bomb.midi raised error
# Processing file  Electric Youth.midi # 609
# Electric Youth.midi raised error
# Processing file  Shape Of My Heart.midi # 610
# Shape Of My Heart.midi raised error
# Processing file  Can't Believe It.midi # 611
# Can't Believe It.midi raised error
# Processing file  What About Love.midi # 612
# What About Love.midi raised error
# Processing file  Sofia.midi # 613
# Sofia.midi raised error
# Processing file  Walking On A Dream.midi # 614
# Walking On A Dream.midi raised error
# Processing file  Say You'll Be There.midi # 615
# Processing file  Bills.midi # 616
# Bills.midi raised error
# Processing file  Treasure.midi # 617
# Treasure.midi raised error
# Processing file  Call The Shots.midi # 618
# Call The Shots.midi raised error
# Processing file  Do What U Want.midi # 619
# Do What U Want.midi raised error
# Processing file  Just Dance.midi # 620
# Just Dance.midi raised error
# Processing file  Problem.midi # 621
# Problem.midi raised error
# Processing file  Hey Beautiful.midi # 622
# Hey Beautiful.midi raised error
# Processing file  The Winner Takes It All.midi # 623
# The Winner Takes It All.midi raised error
# Processing file  Snowman.midi # 624
# Snowman.midi raised error
# Processing file  With Every Heartbeat.midi # 625
# With Every Heartbeat.midi raised error
# Processing file  Lightning Lipgloss Life.midi # 626
# Processing file  Call My Name.midi # 627
# Call My Name.midi raised error
# Processing file  Do It Again ft Royksopp.midi # 628
# Do It Again ft Royksopp.midi raised error
# Processing file  Young Volcanoes.midi # 629
# Young Volcanoes.midi raised error
# Processing file  King Of Wishful Thinking.midi # 630
# King Of Wishful Thinking.midi raised error
# Processing file  Red.midi # 631
# Red.midi raised error
# Processing file  Viva La Vida.midi # 632
# Viva La Vida.midi raised error
# Processing file  Looking for a Dream.midi # 633
# Looking for a Dream.midi raised error
# Processing file  Supreme.midi # 634
# Supreme.midi raised error
# Processing file  Bad Blood.midi # 635
# Bad Blood.midi raised error
# Processing file  The Rain.midi # 636
# The Rain.midi raised error
# Processing file  That Don't Impress Me Much.midi # 637
# That Don't Impress Me Much.midi raised error
# Processing file  All Good Things.midi # 638
# All Good Things.midi raised error
# Processing file  ARTPOP.midi # 639
# ARTPOP.midi raised error
# Processing file  Stop Crying Your Heart Out.midi # 640
# Stop Crying Your Heart Out.midi raised error
# ...
# Processing file  Let It Go.midi # 1058
# Let It Go.midi raised error
# Processing file  Dancing Lasha Tumbai.midi # 1059
# Dancing Lasha Tumbai.midi raised error
# Processing file  Spice Up Your Life.midi # 1060
# Spice Up Your Life.midi raised error
# Processing file  You Should've Gone To School.midi # 1061
# You Should've Gone To School.midi raised error
# Processing file  Live While We're Young.midi # 1062
# Live While We're Young.midi raised error
# Processing file  Rather Be.midi # 1063
# Processing file  Coffee and TV.midi # 1064
# Coffee and TV.midi raised error
# Processing file  She Knows.midi # 1065
# She Knows.midi raised error
# Processing file  We'll Be Coming Back.midi # 1066
# We'll Be Coming Back.midi raised error
# Processing file  All 'Bout The Money.midi # 1067
# All 'Bout The Money.midi raised error
# Processing file  Close To You.midi # 1068
# Close To You.midi raised error
# Processing file  Everything Is Awesome.midi # 1069
# Everything Is Awesome.midi raised error
# Processing file  Cosmic Love.midi # 1070
# Cosmic Love.midi raised error
# Processing file  Ostatni Raz.midi # 1071
# Ostatni Raz.midi raised error
# Processing file  Ribs.midi # 1072
# Ribs.midi raised error
# Processing file  Malibu.midi # 1073
# Malibu.midi raised error
# Processing file  I Love You Always Forever.midi # 1074
# I Love You Always Forever.midi raised error
# Processing file  Slide ft Frank Ocean and Migos.midi # 1075
# Slide ft Frank Ocean and Migos.midi raised error
# Processing file  Speed - Burn and Lotus F1 Team Mix.midi # 1076
# Speed - Burn and Lotus F1 Team Mix.midi raised error
# Processing file  Middle ft Bipolar Sunshine.midi # 1077
# Middle ft Bipolar Sunshine.midi raised error
# Processing file  Midday Star.midi # 1078
# Midday Star.midi raised error
# Processing file  Breathe Me.midi # 1079
# Breathe Me.midi raised error
# Processing file  Shelter.midi # 1080
# Shelter.midi raised error
# Processing file  Figure 8.midi # 1081
# Figure 8.midi raised error
# Processing file  Last Thing On My Mind.midi # 1082
# Last Thing On My Mind.midi raised error
# Processing file  Tennis Court.midi # 1083
# Tennis Court.midi raised error
# Processing file  Eyes Open.midi # 1084
# Eyes Open.midi raised error
# Processing file  Try Everything.midi # 1085
# Try Everything.midi raised error
# Processing file  Love At First Sight.midi # 1086
# Love At First Sight.midi raised error
# Processing file  Nice Guys.midi # 1087
# Nice Guys.midi raised error
# Processing file  Let Go For Tonight.midi # 1088
# Let Go For Tonight.midi raised error
# Processing file  Take You Back Again.midi # 1089
# Take You Back Again.midi raised error
# Processing file  Good Times.midi # 1090
# Good Times.midi raised error
# Processing file  Stand.midi # 1091
# Stand.midi raised error
# Processing file  It's Too Late.midi # 1092
# It's Too Late.midi raised error
# Processing file  Body Say.midi # 1093
# Body Say.midi raised error
# Processing file  Applause.midi # 1094
# Applause.midi raised error
# Processing file  How Deep Is Your Love.midi # 1095
# How Deep Is Your Love.midi raised error
# Processing file  Not Fair.midi # 1096
# Not Fair.midi raised error
# Processing file  White Foxes.midi # 1097
# White Foxes.midi raised error
# Processing file  Misunderstood.midi # 1098
# Misunderstood.midi raised error
# Processing file  I Drive Myself Crazy.midi # 1099
# I Drive Myself Crazy.midi raised error
# Processing file  Heart Attack .midi # 1100
# Heart Attack .midi raised error
# Processing file  These Boots Are Made for Walkin'.midi # 1101
# These Boots Are Made for Walkin'.midi raised error
# Processing file  On Top of the World.midi # 1102
# On Top of the World.midi raised error
# Processing file  All Time Low.midi # 1103
# All Time Low.midi raised error
# Processing file  With You.midi # 1104
# With You.midi raised error
# Processing file  Somebody To Love Me.midi # 1105
# Somebody To Love Me.midi raised error
# Processing file  Granda.midi # 1106
# Granda.midi raised error
# Processing file  Say My Name ft Zyra.midi # 1107
# Say My Name ft Zyra.midi raised error
# Processing file  Genie.midi # 1108
# Genie.midi raised error
# Processing file  1901.midi # 1109
# 1901.midi raised error
# Processing file  Money Money Money.midi # 1110
# Money Money Money.midi raised error
# Processing file  New Rules.midi # 1111
# New Rules.midi raised error
# Processing file  Amnesia.midi # 1112
# Amnesia.midi raised error
# Processing file  Piano Man.midi # 1113
# Piano Man.midi raised error
# Processing file  Rhythm Of Love.midi # 1114
# Rhythm Of Love.midi raised error
# Processing file  Longing for Lullabies ft Titiyo.midi # 1115
# Longing for Lullabies ft Titiyo.midi raised error
# Processing file  Buddy Holly.midi # 1116
# Buddy Holly.midi raised error
# Processing file  No More Sad Song.midi # 1117
# No More Sad Song.midi raised error
# Processing file  Enjoy the Silence.midi # 1118
# Enjoy the Silence.midi raised error
# Processing file  Can't Beat The Feeling.midi # 1119
# Can't Beat The Feeling.midi raised error
# Processing file  Put It In Your Pocket.midi # 1120
# Put It In Your Pocket.midi raised error
# Processing file  Heroes.midi # 1121
# Heroes.midi raised error
# Processing file  Knowing Me Knowing You.midi # 1122
# Knowing Me Knowing You.midi raised error
# Processing file  Fix You.midi # 1123
# Fix You.midi raised error
# Processing file  Poker Face Acoustic.midi # 1124
# Poker Face Acoustic.midi raised error
# Processing file  Groove Is In The Heart.midi # 1125
# Groove Is In The Heart.midi raised error
# Processing file  First Time.midi # 1126
# First Time.midi raised error
# Processing file  Girls Just Want To Have Fun.midi # 1127
# Girls Just Want To Have Fun.midi raised error
# Processing file  One Step at a Time.midi # 1128
# One Step at a Time.midi raised error
# Processing file  Dynamite.midi # 1129
# Dynamite.midi raised error
# Processing file  Earned It.midi # 1130
# Earned It.midi raised error
# Processing file  Tell It To My Heart.midi # 1131
# Tell It To My Heart.midi raised error
# Processing file  Whiskey Lullaby.midi # 1132
# Whiskey Lullaby.midi raised error
# Processing file  C est La Vie.midi # 1133
# C est La Vie.midi raised error
# Processing file  Something Just Like This.midi # 1134
# Something Just Like This.midi raised error
# Processing file  Nasty.midi # 1135
# Nasty.midi raised error
# Processing file  Ass Back Home.midi # 1136
# Processing file  Bad Romance.midi # 1137
# Bad Romance.midi raised error
# Processing file  Hard Out Here.midi # 1138
# Hard Out Here.midi raised error
# Processing file  Like I Can .midi # 1139
# Like I Can .midi raised error
# Processing file  I Have Nothing.midi # 1140
# I Have Nothing.midi raised error
# Processing file  FourFiveSeconds.midi # 1141
# FourFiveSeconds.midi raised error
# Processing file  Every Breath You Take.midi # 1142
# Every Breath You Take.midi raised error
# Processing file  Que Sera.midi # 1143
# Que Sera.midi raised error
# Processing file  Sinful ft I See Monstas.midi # 1144
# Sinful ft I See Monstas.midi raised error
# Processing file  Candy.midi # 1145
# Candy.midi raised error
# Processing file  Don't Think I'm Not.midi # 1146
# Don't Think I'm Not.midi raised error
# Processing file  Doin' it Right.midi # 1147
# Doin' it Right.midi raised error
# Processing file  Love The Way You Lie Part 2.midi # 1148
# Love The Way You Lie Part 2.midi raised error
# Processing file  Monster.midi # 1149
# Monster.midi raised error
# Processing file  Promised You A Miracle.midi # 1150
# Promised You A Miracle.midi raised error
# Processing file  Hall of Fame.midi # 1151
# Hall of Fame.midi raised error
# Processing file  Cry Me A River.midi # 1152
# Cry Me A River.midi raised error
# Processing file  Love's Got A Hold On My Heart.midi # 1153
# Love's Got A Hold On My Heart.midi raised error
# Processing file  i hate u i love u.midi # 1154
# i hate u i love u.midi raised error
# Processing file  Breakaway.midi # 1155
# Breakaway.midi raised error
# Processing file  Mr Saxobeat.midi # 1156
# Mr Saxobeat.midi raised error
# Processing file  Derniere Danse.midi # 1157
# Derniere Danse.midi raised error
# Processing file  What Kind of Pokemon Are You.midi # 1158
# What Kind of Pokemon Are You.midi raised error
# Processing file  Club Can't Handle Me.midi # 1159
# Club Can't Handle Me.midi raised error
# Processing file  Black Swan.midi # 1160
# Black Swan.midi raised error
# Processing file  Sandstorm.midi # 1161
# Sandstorm.midi raised error
# Processing file  Find You.midi # 1162
# Find You.midi raised error
# Processing file  I Melt With You.midi # 1163
# I Melt With You.midi raised error
# Processing file  It's Time.midi # 1164
# It's Time.midi raised error
# Processing file  The Sun And The Rain.midi # 1165
# The Sun And The Rain.midi raised error
# Processing file  Annie You Save Me.midi # 1166
# Annie You Save Me.midi raised error
# Processing file  Can't Get You Out Of My Head.midi # 1167
# Can't Get You Out Of My Head.midi raised error
# Processing file  All Cried Out.midi # 1168
# All Cried Out.midi raised error
# Processing file  Where Did Our Love Go.midi # 1169
# Where Did Our Love Go.midi raised error
# Processing file  Killing Me Softly.midi # 1170
# Killing Me Softly.midi raised error
# Processing file  Baby Don't Lie.midi # 1171
# Baby Don't Lie.midi raised error
# Processing file  Maneater.midi # 1172
# Maneater.midi raised error
# Processing file  Cold Water ft Justin Bieber and MO.midi # 1173
# Cold Water ft Justin Bieber and MO.midi raised error
# Processing file  Money.midi # 1174
# Money.midi raised error
# Processing file  This Land Is Your Land.midi # 1175
# This Land Is Your Land.midi raised error
# Processing file  Heavy Cross.midi # 1176
# Heavy Cross.midi raised error
# Processing file  Hey Mickey.midi # 1177
# Hey Mickey.midi raised error
# Processing file  Waka Waka.midi # 1178
# Waka Waka.midi raised error
# Processing file  Heaven is a Place on Earth.midi # 1179
# Heaven is a Place on Earth.midi raised error
# Processing file  Love is Gone.midi # 1180
# Love is Gone.midi raised error
# Processing file  Roar.midi # 1181
# Roar.midi raised error
# Processing file  I Need to Know.midi # 1182
# I Need to Know.midi raised error
# Processing file  Dreamlife - Antics Remix.midi # 1183
# Dreamlife - Antics Remix.midi raised error
# Processing file  Nah Neh Nah.midi # 1184
# Nah Neh Nah.midi raised error
# Processing file  Stayin' Alive.midi # 1185
# Processing file  Ex's And Oh's.midi # 1186
# Ex's And Oh's.midi raised error
# Processing file  I Like That.midi # 1187
# I Like That.midi raised error
# Processing file  Charlie Brown.midi # 1188
# Charlie Brown.midi raised error
# Processing file  Rhythm Of The Night.midi # 1189
# Rhythm Of The Night.midi raised error
# Processing file  Holiday.midi # 1190
# Holiday.midi raised error
# Processing file  Around My Heart.midi # 1191
# Around My Heart.midi raised error
# Processing file  Kids ft Kylie Minogue.midi # 1192
# Kids ft Kylie Minogue.midi raised error
# Processing file  All The Small Things.midi # 1193
# All The Small Things.midi raised error
# Processing file  True Colors.midi # 1194
# True Colors.midi raised error
# Processing file  I Believe In You.midi # 1195
# I Believe In You.midi raised error
# Processing file  Mer Girl.midi # 1196
# Processing file  The Hardest Thing.midi # 1197
# The Hardest Thing.midi raised error
# Processing file  Nessun Grado Di Separazione.midi # 1198
# Nessun Grado Di Separazione.midi raised error
# Processing file  Gangnam Style.midi # 1199
# Gangnam Style.midi raised error
# Processing file  Behind These Hazel Eyes.midi # 1200
# Behind These Hazel Eyes.midi raised error
# Processing file  When The Beat Drops Out.midi # 1201
# When The Beat Drops Out.midi raised error
# Processing file  Honey To The Bee.midi # 1202
# Honey To The Bee.midi raised error
# Processing file  Haven't Met You Yet.midi # 1203
# Haven't Met You Yet.midi raised error
# Processing file  Side to Side.midi # 1204
# Side to Side.midi raised error
# Processing file  Alejandro.midi # 1205
# Alejandro.midi raised error
# Processing file  Be My Baby.midi # 1206
# Be My Baby.midi raised error
# Processing file  That's Falling in Love.midi # 1207
# That's Falling in Love.midi raised error
# Processing file  4 In The Morning.midi # 1208
# 4 In The Morning.midi raised error
# Processing file  Red Light Special.midi # 1209
# Red Light Special.midi raised error
# Processing file  I Didn't Just Come Here To Dance.midi # 1210
# I Didn't Just Come Here To Dance.midi raised error
# Processing file  Let It Be.midi # 1211
# Let It Be.midi raised error
# Processing file  Can't Fight The Moonlight.midi # 1212
# Can't Fight The Moonlight.midi raised error
# Processing file  Latch.midi # 1213
# Latch.midi raised error
# Processing file  All Over The World.midi # 1214
# All Over The World.midi raised error
# Processing file  Want To Want Me.midi # 1215
# Want To Want Me.midi raised error
# Processing file  Single Ladies.midi # 1216
# Single Ladies.midi raised error
# Processing file  I Turn To You.midi # 1217
# I Turn To You.midi raised error
# Processing file  Girls.midi # 1218
# Girls.midi raised error
# Processing file  Where Have You Been.midi # 1219
# Where Have You Been.midi raised error
# Processing file  Leave It All To Me.midi # 1220
# Leave It All To Me.midi raised error
# Processing file  Need Ur Luv.midi # 1221
# Need Ur Luv.midi raised error
# Processing file  Shake It Off.midi # 1222
# Shake It Off.midi raised error
# Processing file  All The Man That I Need.midi # 1223
# All The Man That I Need.midi raised error
# Processing file  Here And Now.midi # 1224
# Here And Now.midi raised error
# Processing file  Yellow Flicker Beat.midi # 1225
# Yellow Flicker Beat.midi raised error
# Processing file  Birthday.midi # 1226
# Birthday.midi raised error
# Processing file  La Bamba.midi # 1227
# La Bamba.midi raised error
# Processing file  All I Do Is Win.midi # 1228
# All I Do Is Win.midi raised error
# Processing file  Hey Soul Sister.midi # 1229
# Hey Soul Sister.midi raised error
# Processing file  LKY Fansku Tapi Hatersku.midi # 1230
# LKY Fansku Tapi Hatersku.midi raised error
# Processing file  Dreaming With A Broken Heart.midi # 1231
# Dreaming With A Broken Heart.midi raised error
# Processing file  C'est La Vie.midi # 1232
# C'est La Vie.midi raised error
# Processing file  I'm A Sinner.midi # 1233
# I'm A Sinner.midi raised error
# Processing file  King.midi # 1234
# King.midi raised error
# Processing file  Desenchantee.midi # 1235
# Desenchantee.midi raised error
# Processing file  El Poeta.midi # 1236
# El Poeta.midi raised error
# Processing file  Fight Song.midi # 1237
# Fight Song.midi raised error
# Processing file  Never Let Me Down Again.midi # 1238
# Never Let Me Down Again.midi raised error
# Processing file  Primadonna.midi # 1239
# Primadonna.midi raised error
# Processing file  Aura.midi # 1240
# Aura.midi raised error
# Processing file  Be Alright.midi # 1241
# Be Alright.midi raised error
# Processing file  A Little Too Not Over You.midi # 1242
# A Little Too Not Over You.midi raised error
# Processing file  Africa.midi # 1243
# Africa.midi raised error
# Processing file  All The Things She Said.midi # 1244
# All The Things She Said.midi raised error
# Processing file  Fidelity.midi # 1245
# Fidelity.midi raised error
# Processing file  With A Few Good Friends.midi # 1246
# With A Few Good Friends.midi raised error
# Processing file  Toothbrush.midi # 1247
# Toothbrush.midi raised error
# Processing file  Beverly Hills Cop Theme - Axel F.midi # 1248
# Beverly Hills Cop Theme - Axel F.midi raised error
# Processing file  Disco Heaven.midi # 1249
# Disco Heaven.midi raised error
# Processing file  Bug A Boo.midi # 1250
# Bug A Boo.midi raised error
# Processing file  I Want It That Way.midi # 1251
# I Want It That Way.midi raised error
# Processing file  Don't Stop 'Till You Get Enough.midi # 1252
# Don't Stop 'Till You Get Enough.midi raised error
# Processing file  Scatman.midi # 1253
# Scatman.midi raised error
# Processing file  Material Girl.midi # 1254
# Material Girl.midi raised error
# Processing file  Do It.midi # 1255
# Do It.midi raised error
# Processing file  Girlfriend.midi # 1256
# Girlfriend.midi raised error
# Processing file  The Lazy Song.midi # 1257
# The Lazy Song.midi raised error
# Processing file  Say It Ain't So.midi # 1258
# Say It Ain't So.midi raised error
# Processing file  Agent Yoru wo Yuku Remix B.midi # 1259
# Agent Yoru wo Yuku Remix B.midi raised error
# Processing file  Pyramids.midi # 1260
# Pyramids.midi raised error
# Processing file  Parachute.midi # 1261
# Parachute.midi raised error
# 1226 0 1261

# %%
Cur_X = np.asarray(Cur_X)
print Cur_X.shape
chromaVec = np.asarray(chromaVec)
print chromaVec.shape

# %%
np.save('Cur_X',Cur_X)
np.save('chromaVec',chromaVec)

# %%
pygame.init()
def play(midiFile):
    pygame.mixer.music.load(midiFile)
    pygame.mixer.music.play()

# %%
#playing the resultant midi produced by the generator.
result = np.load('result.npy')
print result.shape
song = noteStateMatrixToMidi(result)
midi.write_midifile("result_tune.mid", song)
play('result_tune.mid')
